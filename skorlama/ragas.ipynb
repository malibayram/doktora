# %%
from datasets import Dataset 
import os
from ragas import evaluate
from ragas.metrics import answer_similarity
import pandas as pd

# %%
# https://docs.ragas.io/en/stable/concepts/metrics/semantic_similarity.html

# %%
os.environ["OPENAI_API_KEY"] = "sk-proj-ozsRlQGengo3IrYKq1ppT3BlbkFJpftzn4iwQaWpOJPV5oSp"

# %%
data_samples = {
    'question': ['When was the first super bowl?', 'Who won the most super bowls?'],
    'answer': ['The first superbowl was held on Jan 15, 1967', 'The most super bowls have been won by The New England Patriots'],
    'ground_truth': ['The first superbowl was held on January 15, 1967', 'The New England Patriots have won the Super Bowl a record six times']
}

dataset = Dataset.from_dict(data_samples)
dataset
# Out:
# Dataset({
#     features: ['question', 'answer', 'ground_truth'],
#     num_rows: 2
# })

# %%
score = evaluate(dataset, metrics=[answer_similarity])
score.to_pandas()
# Out:
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.64it/s]
#                          question  \
# 0  When was the first super bowl?
# 1   Who won the most super bowls?
#
#                                               answer  \
# 0       The first superbowl was held on Jan 15, 1967
# 1  The most super bowls have been won by The New ...
#
#                                         ground_truth  answer_similarity
# 0   The first superbowl was held on January 15, 1967           0.996372
# 1  The New England Patriots have won the Super Bo...           0.924343

# %%
answers = pd.read_csv('./generated_answers_llama3_8b.csv')
answers
# Out:
#                                       question_content  \
# 0    Merhabalar Benim sol alt karın boslugumda elim...
# 1    Merhaba Hocam.. 26 yaşındaki kardeşim 15 gün ö...
# 2    merhabalar! 15 yaşımda primer amenore teşhisiy...
# 3    sayın doktor bey annem dün akşam sag tarafında...
# 4    merhaba hocam benim kalçamda eğiklik var belde...
# ..                                                 ...
# 495  hocam merhaba 7 haftalık hamileyim.bende sebor...
# 496  iyi günler doktor bey... bizim 8 yaşında bir k...
# 497  Merhaba.Benim 3 aylık bir oğlum var.Sadece ann...
# 498  avni bey,benim şikayetim 3 aydır sol kulak mem...
# 499  Hocam merhaba adet dönemindeyim çok şiddetli a...
#
#                                       generated_answer  \
# 0    Merhaba öncelikle geçmiş olsun. ultrason sonuc...
# 1    Merhaba, öncelikle geçmiş olsun. Bu tür yarala...
# 2    Merhaba, öncelikle muayene olmadan net bir şey...
# 3    Sayın Sevinç Hanım, Annenizin ağrısının kalple...
# 4    Merhabalar; Size bir ortopedi uzmanına muayene...
# ..                                                 ...
# 495  Merhaba, Bu ilacın bebekte herhangi bir yan et...
# 496  Merhabalar; Öncelikle Geçmiş olsun; Eşinizin s...
# 497  Merhaba, meme ucunda şişlik ve kızarıklık meme...
# 498  Merhaba, Kulak arkasındaki ağrı sebebiyle KBB ...
# 499  Merhaba, adet kanamasını kesen ilaçların hepsi...
#
#                                        original_answer  \
# 0    Burda yazan sonuçlara göre önemli bir hastalık...
# 1    Bu konudaki en sağlıklı cevabı, nöroloji uzman...
# 2    Adetin 3. günü hormon tahlili ve ultrason ile ...
# 3    Tabii bazı kalp rahatsızlıkları karın ağrısı d...
# 4    Büyük ihtimalle uygun egzersiz programları siz...
# ..                                                 ...
# 495  Sayın Burcu Hanım: Bu madde antifungal yani ma...
# 496  NORMAL SINIRLARDA UROLOJI UZMANINA MUAYENE OLU...
# 497  puerperal mastit denen memede enfeksiyon başla...
# 498  Zerrin hanım, madem Ankarada bulunuyorsunuz lü...
# 499  Merhaba ağrı kesici kullanabilirsiniz. Ağrı ke...
#
#                                       answer_llama3_8b
# 0    Merhabalar!\n\nI'd be happy to help you interp...
# 1    Merhaba, sevgili kardeşim!\n\nİyi haberliyim, ...
# 2    Merhabalar!\n\nFirst of all, congratulations o...
# 3    I'm not a doctor, but I can try to help you un...
# 4    Merhaba! Kalça eğriliği ve belde çukurluk çok ...
# ..                                                 ...
# 495  Merhaba hocam, gebeliğinizi 7 haftalık olarak ...
# 496  Iyi günler, doktorunuz olarak, sizin soruların...
# 497  Merhaba! Congratulations on breastfeeding your...
# 498  It seems like you're experiencing a persistent...
# 499  Merhaba! First, please don't worry, it's norma...
#
# [500 rows x 4 columns]

# %%
# print column names
print(answers.columns)
# Out:
# Index(['question_content', 'generated_answer', 'original_answer',
#        'answer_llama3_8b'],
#       dtype='object')

# %%
""" data_samples = {
    'question': ['When was the first super bowl?', 'Who won the most super bowls?'],
    'answer': ['The first superbowl was held on Jan 15, 1967', 'The most super bowls have been won by The New England Patriots'],
    'contexts' : [['The First AFL–NFL World Championship Game was an American football game played on January 15, 1967, at the Los Angeles Memorial Coliseum in Los Angeles,'], 
    ['The Green Bay Packers...Green Bay, Wisconsin.','The Packers compete...Football Conference']],
    'ground_truth': ['The first superbowl was held on January 15, 1967', 'The New England Patriots have won the Super Bowl a record six times']
} """

""" answers.columns => ['question_content', 'generated_answer', 'original_answer',
       'answer_llama3_8b'] """

data_samples['question'] = answers['question_content'].tolist()
data_samples['answer'] = answers['generated_answer'].tolist()
data_samples['ground_truth'] = answers['original_answer'].tolist()

dataset = Dataset.from_dict(data_samples)
dataset
# Out:
# Dataset({
#     features: ['question', 'answer', 'ground_truth'],
#     num_rows: 500
# })

# %%
score = evaluate(dataset, metrics=[answer_similarity])
score_df = score.to_pandas()
score_df.to_csv('./ragas_score_df.csv')
score_df
# Out:
# Evaluating: 100%|██████████| 500/500 [00:20<00:00, 24.91it/s]
#                                               question  \
# 0    Merhabalar Benim sol alt karın boslugumda elim...
# 1    Merhaba Hocam.. 26 yaşındaki kardeşim 15 gün ö...
# 2    merhabalar! 15 yaşımda primer amenore teşhisiy...
# 3    sayın doktor bey annem dün akşam sag tarafında...
# 4    merhaba hocam benim kalçamda eğiklik var belde...
# ..                                                 ...
# 495  hocam merhaba 7 haftalık hamileyim.bende sebor...
# 496  iyi günler doktor bey... bizim 8 yaşında bir k...
# 497  Merhaba.Benim 3 aylık bir oğlum var.Sadece ann...
# 498  avni bey,benim şikayetim 3 aydır sol kulak mem...
# 499  Hocam merhaba adet dönemindeyim çok şiddetli a...
#
#                                                 answer  \
# 0    Merhaba öncelikle geçmiş olsun. ultrason sonuc...
# 1    Merhaba, öncelikle geçmiş olsun. Bu tür yarala...
# 2    Merhaba, öncelikle muayene olmadan net bir şey...
# 3    Sayın Sevinç Hanım, Annenizin ağrısının kalple...
# 4    Merhabalar; Size bir ortopedi uzmanına muayene...
# ..                                                 ...
# 495  Merhaba, Bu ilacın bebekte herhangi bir yan et...
# 496  Merhabalar; Öncelikle Geçmiş olsun; Eşinizin s...
# 497  Merhaba, meme ucunda şişlik ve kızarıklık meme...
# 498  Merhaba, Kulak arkasındaki ağrı sebebiyle KBB ...
# 499  Merhaba, adet kanamasını kesen ilaçların hepsi...
#
#                                           ground_truth  answer_similarity
# 0    Burda yazan sonuçlara göre önemli bir hastalık...           0.863566
# 1    Bu konudaki en sağlıklı cevabı, nöroloji uzman...           0.859840
# 2    Adetin 3. günü hormon tahlili ve ultrason ile ...           0.890020
# 3    Tabii bazı kalp rahatsızlıkları karın ağrısı d...           0.862148
# 4    Büyük ihtimalle uygun egzersiz programları siz...           0.885885
# ..                                                 ...                ...
# 495  Sayın Burcu Hanım: Bu madde antifungal yani ma...           0.884692
# 496  NORMAL SINIRLARDA UROLOJI UZMANINA MUAYENE OLU...           0.829627
# 497  puerperal mastit denen memede enfeksiyon başla...           0.832994
# 498  Zerrin hanım, madem Ankarada bulunuyorsunuz lü...           0.837161
# 499  Merhaba ağrı kesici kullanabilirsiniz. Ağrı ke...           0.913464
#
# [500 rows x 4 columns]

# %%
data_samples['question'] = answers['question_content'].tolist()
data_samples['answer'] = answers['answer_llama3_8b'].tolist()
data_samples['ground_truth'] = answers['original_answer'].tolist()

dataset = Dataset.from_dict(data_samples)
dataset
# Out:
# Dataset({
#     features: ['question', 'answer', 'ground_truth'],
#     num_rows: 500
# })

# %%
score = evaluate(dataset, metrics=[answer_similarity])
score_df = score.to_pandas()
score_df.to_csv('./ragas_score_llama3_df.csv')
score_df
# Out:
# Evaluating: 100%|██████████| 500/500 [00:19<00:00, 25.69it/s]
#                                               question  \
# 0    Merhabalar Benim sol alt karın boslugumda elim...
# 1    Merhaba Hocam.. 26 yaşındaki kardeşim 15 gün ö...
# 2    merhabalar! 15 yaşımda primer amenore teşhisiy...
# 3    sayın doktor bey annem dün akşam sag tarafında...
# 4    merhaba hocam benim kalçamda eğiklik var belde...
# ..                                                 ...
# 495  hocam merhaba 7 haftalık hamileyim.bende sebor...
# 496  iyi günler doktor bey... bizim 8 yaşında bir k...
# 497  Merhaba.Benim 3 aylık bir oğlum var.Sadece ann...
# 498  avni bey,benim şikayetim 3 aydır sol kulak mem...
# 499  Hocam merhaba adet dönemindeyim çok şiddetli a...
#
#                                                 answer  \
# 0    Merhabalar!\n\nI'd be happy to help you interp...
# 1    Merhaba, sevgili kardeşim!\n\nİyi haberliyim, ...
# 2    Merhabalar!\n\nFirst of all, congratulations o...
# 3    I'm not a doctor, but I can try to help you un...
# 4    Merhaba! Kalça eğriliği ve belde çukurluk çok ...
# ..                                                 ...
# 495  Merhaba hocam, gebeliğinizi 7 haftalık olarak ...
# 496  Iyi günler, doktorunuz olarak, sizin soruların...
# 497  Merhaba! Congratulations on breastfeeding your...
# 498  It seems like you're experiencing a persistent...
# 499  Merhaba! First, please don't worry, it's norma...
#
#                                           ground_truth  answer_similarity
# 0    Burda yazan sonuçlara göre önemli bir hastalık...           0.782333
# 1    Bu konudaki en sağlıklı cevabı, nöroloji uzman...           0.806390
# 2    Adetin 3. günü hormon tahlili ve ultrason ile ...           0.804275
# 3    Tabii bazı kalp rahatsızlıkları karın ağrısı d...           0.772662
# 4    Büyük ihtimalle uygun egzersiz programları siz...           0.803725
# ..                                                 ...                ...
# 495  Sayın Burcu Hanım: Bu madde antifungal yani ma...           0.879474
# 496  NORMAL SINIRLARDA UROLOJI UZMANINA MUAYENE OLU...           0.828124
# 497  puerperal mastit denen memede enfeksiyon başla...           0.790239
# 498  Zerrin hanım, madem Ankarada bulunuyorsunuz lü...           0.723634
# 499  Merhaba ağrı kesici kullanabilirsiniz. Ağrı ke...           0.788376
#
# [500 rows x 4 columns]

# %%
score_df['answer_similarity'].mean()
# Out:
# 0.7872567928631206

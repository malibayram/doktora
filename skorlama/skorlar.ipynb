# %%
import pandas as pd

# %%
data = pd.read_csv('generated_answers_oct_28_with_similarities_and_scores.csv')
data
# Out:
#                                       question_content  \
# 0    Merhabalar Benim sol alt karın boslugumda elim...
# 1    Merhaba Hocam.. 26 yaşındaki kardeşim 15 gün ö...
# 2    merhabalar! 15 yaşımda primer amenore teşhisiy...
# 3    sayın doktor bey annem dün akşam sag tarafında...
# 4    merhaba hocam benim kalçamda eğiklik var belde...
# ..                                                 ...
# 495  hocam merhaba 7 haftalık hamileyim.bende sebor...
# 496  iyi günler doktor bey... bizim 8 yaşında bir k...
# 497  Merhaba.Benim 3 aylık bir oğlum var.Sadece ann...
# 498  avni bey,benim şikayetim 3 aydır sol kulak mem...
# 499  Hocam merhaba adet dönemindeyim çok şiddetli a...
#
#                                       generated_answer  \
# 0    Merhaba öncelikle geçmiş olsun. ultrason sonuc...
# 1    Merhaba, öncelikle geçmiş olsun. Bu tür yarala...
# 2    Merhaba, öncelikle muayene olmadan net bir şey...
# 3    Sayın Sevinç Hanım, Annenizin ağrısının kalple...
# ...

# %%
# change gpt3.5_score_generated_answer and gpt3.5_score_original_answer from 8/10 to 0.8

for i, row in data.iterrows():
    value1 = str(row['gpt3.5_score_generated_answer'])
    # if value1 contains a slash, take the first part
    if '/' in value1:
        value1 = value1.split('/')[0]
    value2 = str(row['gpt3.5_score_original_answer'])
    if '/' in value2:
        value2 = value2.split('/')[0]
    value1 = float(value1)
    value2 = float(value2)
    print(value1, value2)
    if value1 > 0:
        data.at[i, 'gpt3.5_score_generated_answer'] = value1 / 10
    if value2 > 0:
        data.at[i, 'gpt3.5_score_original_answer'] = value2 / 10
# Out:
# 7.0 8.0
# 8.0 7.0
# 8.0 7.0
# 7.0 8.0
# 8.0 7.0
# 7.0 8.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 6.0 7.0
# 7.0 8.0
# 8.0 7.0
# 8.0 7.0
# 7.0 8.0
# 8.0 7.0
# 9.0 8.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 9.0 8.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 9.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 7.0 8.0
# 8.0 7.0
# 7.0 8.0
# 8.0 7.0
# 7.0 8.0
# 8.0 7.0
# 7.0 8.0
# 8.0 7.0
# 7.0 8.0
# 8.0 7.0
# 7.0 8.0
# 8.0 7.0
# 7.0 8.0
# 7.0 8.0
# 8.0 7.0
# 9.0 8.0
# 7.0 8.0
# 8.0 7.0
# 6.0 7.0
# 7.0 8.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 7.0 8.0
# 8.0 9.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 7.0 8.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 6.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 7.0 8.0
# 8.0 7.0
# 9.0 8.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 8.0 7.0
# 7.0 8.0
# 7.0 8.0
# 8.0 7.0
# 7.0 8.0
# 9.0 8.0
# 8.0 7.0
# 8.0 7.0
# ...

# %%
data
# Out:
#                                       question_content  \
# 0    Merhabalar Benim sol alt karın boslugumda elim...
# 1    Merhaba Hocam.. 26 yaşındaki kardeşim 15 gün ö...
# 2    merhabalar! 15 yaşımda primer amenore teşhisiy...
# 3    sayın doktor bey annem dün akşam sag tarafında...
# 4    merhaba hocam benim kalçamda eğiklik var belde...
# ..                                                 ...
# 495  hocam merhaba 7 haftalık hamileyim.bende sebor...
# 496  iyi günler doktor bey... bizim 8 yaşında bir k...
# 497  Merhaba.Benim 3 aylık bir oğlum var.Sadece ann...
# 498  avni bey,benim şikayetim 3 aydır sol kulak mem...
# 499  Hocam merhaba adet dönemindeyim çok şiddetli a...
#
#                                       generated_answer  \
# 0    Merhaba öncelikle geçmiş olsun. ultrason sonuc...
# 1    Merhaba, öncelikle geçmiş olsun. Bu tür yarala...
# 2    Merhaba, öncelikle muayene olmadan net bir şey...
# 3    Sayın Sevinç Hanım, Annenizin ağrısının kalple...
# ...

# %%
# get average of each column original_answer_to_generated_answer_similarity, original_answer_to_llama3_8b_answer_similarity, gpt3.5_score_generated_answer, gpt3.5_score_original_answer
oa_to_ga = data['original_answer_to_doktorllama3_cosmos_answer_similarity'].mean()
oa_to_la = data['original_answer_to_llama3_8b_answer_similarity'].mean()
gpt3_5_ga = data['gpt_score_oct_28_doktorllama3_cosmos_answer'].mean()
gpt3_5_oa = data['gpt_score_oct_28_cosmos_original_answer'].mean()

# %%
print("Orjinal cevabın bizim modelin ürettiği cevaba benzerlik ortalaması:", oa_to_ga)
print("Orjinal cevabın llama3_8b modelin ürettiği cevaba benzerlik ortalaması:", oa_to_la)
print("Orjinal cevaba GPT-3.5'in verdiği puan ortalaması:", gpt3_5_ga)
print("Bizim modelin ürettiği cevaba GPT-3.5'in verdiği puan ortalaması:", gpt3_5_oa)

benzerlik_skoruna_gore_gelisme = round((oa_to_ga - oa_to_la) / oa_to_la * 100, 2)
gpt3_5_skoruna_gore_fark = round((gpt3_5_ga - gpt3_5_oa) / gpt3_5_oa * 100, 2)
print("Orjinal cevabın bizim modelin ürettiği cevaba benzerlik ortalamasındaki gelişme oranı:", benzerlik_skoruna_gore_gelisme, "%")
print("Bizim modelin ürettiği cevaba GPT-3.5'in verdiği puan ortalamasındaki fark oranı:", gpt3_5_skoruna_gore_fark, "%")
# Out:
# Orjinal cevabın bizim modelin ürettiği cevaba benzerlik ortalaması: 0.5108499999999999
# Orjinal cevabın llama3_8b modelin ürettiği cevaba benzerlik ortalaması: 0.46271
# Orjinal cevaba GPT-3.5'in verdiği puan ortalaması: 8.896
# Bizim modelin ürettiği cevaba GPT-3.5'in verdiği puan ortalaması: 7.789156626506024
# Orjinal cevabın bizim modelin ürettiği cevaba benzerlik ortalamasındaki gelişme oranı: 10.4 %
# Bizim modelin ürettiği cevaba GPT-3.5'in verdiği puan ortalamasındaki fark oranı: 14.21 %

# %%
scores_dict = {
    "Orjinal cevabın bizim modelin ürettiği cevaba benzerlik ortalaması": oa_to_ga,
    "Orjinal cevabın llama3_8b modelin ürettiği cevaba benzerlik ortalaması": oa_to_la,
    "Orjinal cevaba GPT-3.5'in verdiği puan ortalaması": gpt3_5_ga,
    "Bizim modelin ürettiği cevaba GPT-3.5'in verdiği puan ortalaması": gpt3_5_oa,
    "Orjinal cevabın bizim modelin ürettiği cevaba benzerlik ortalamasındaki gelişme oranı": benzerlik_skoruna_gore_gelisme,
    "Bizim modelin ürettiği cevaba GPT-3.5'in verdiği puan ortalamasındaki fark oranı": gpt3_5_skoruna_gore_fark
}

scores_dict_df = pd.DataFrame(scores_dict.items(), columns=['Metric', 'Value'])
scores_dict_df.to_csv('oct_28_cosmos_scores_dict.csv', index=False)
scores_dict_df
# Out:
#                                               Metric      Value
# 0  Orjinal cevabın bizim modelin ürettiği cevaba ...   0.510850
# 1  Orjinal cevabın llama3_8b modelin ürettiği cev...   0.462710
# 2  Orjinal cevaba GPT-3.5'in verdiği puan ortalaması   8.896000
# 3  Bizim modelin ürettiği cevaba GPT-3.5'in verdi...   7.789157
# 4  Orjinal cevabın bizim modelin ürettiği cevaba ...  10.400000
# 5  Bizim modelin ürettiği cevaba GPT-3.5'in verdi...  14.210000

# %%
# https://zenodo.org/records/45901
